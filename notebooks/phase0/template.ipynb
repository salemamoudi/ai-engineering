# %% [markdown]
# # AI Engineering Notebook Template
#
# ## Setup
# This notebook is for AI Engineering from Scratch.

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import torch

print(f'Python: {sys.version[:50]}')
print(f'PyTorch: {torch.__version__}')
print(f'CUDA: {torch.cuda.is_available()}')
