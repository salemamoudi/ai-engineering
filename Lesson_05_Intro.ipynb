# %%
import sys
import torch
import numpy as np

print(f"Python: {sys.version[:50]}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"NumPy: {np.__version__}")
print("✅ Environment is working!")
# Out:
# Python: 3.12.13 (main, Jul 18 2026, 17:02:19) [Clang 22.1.
# PyTorch: 2.13.0+cu130
# CUDA available: True
# NumPy: 1.26.4
# ✅ Environment is working!

# %%
import requests

def ask_ollama(prompt, model="tinyllama"):
    try:
        response = requests.post(
            "http://localhost:11434/api/generate",
            json={"model": model, "prompt": prompt, "stream": False},
            timeout=60
        )
        return response.json().get('response', '')
    except Exception as e:
        return f"Error: {e}"

# Test it
result = ask_ollama("What is AI Engineering? Answer in one sentence.")
print(result)

# %%
# Lesson 05: Jupyter Notebooks for AI Engineering

## Overview
This notebook introduces Jupyter for AI development.

## Key Topics
- ✅ Interactive Python development
- ✅ Data visualization
- ✅ AI model prototyping
- ✅ Experiment tracking

## Progress
- [x] Installed Jupyter Lab
- [x] Created first notebook
- [x] Tested Python
- [x] Integrated Ollama
- [ ] Created visualizations
- [ ] Built interactive widgets
# Out:
#   Cell In[3], line 7
#     - ✅ Interactive Python development
#       ^
# SyntaxError: invalid character '✅' (U+2705)

# %% [markdown]
# # Lesson 05: Jupyter Notebooks for AI Engineering
#
# ## Overview
# This notebook introduces Jupyter for AI development.
#
# ## Key Topics
# - ✅ Interactive Python development
# - ✅ Data visualization
# - ✅ AI model prototyping
# - ✅ Experiment tracking
#
# ## Progress
# - [x] Installed Jupyter Lab
# - [x] Created first notebook
# - [x] Tested Python
# - [x] Integrated Ollama
# - [ ] Created visualizations
# - [ ] Built interactive widgets

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# Create data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'b-', linewidth=2, label='sin(x)')
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import requests

def ask_ai(prompt):
    try:
        response = requests.post(
            "http://localhost:11434/api/generate",
            json={"model": "tinyllama", "prompt": prompt, "stream": False},
            timeout=60
        )
        return response.json().get('response', '')
    except Exception as e:
        return f"Error: {e}"

# Create widgets
input_box = widgets.Textarea(
    placeholder='Type your question here...',
    description='Question:',
    layout=widgets.Layout(width='90%', height='80px')
)

button = widgets.Button(description='Ask AI', button_style='primary')
output = widgets.Output()

def on_click(b):
    with output:
        clear_output()
        if input_box.value:
            print("🤔 Question:", input_box.value)
            print("---")
            print("🤖 Answer:", ask_ai(input_box.value))
        else:
            print("Please enter a question.")

button.on_click(on_click)

display(input_box, button, output)
# Out:
# Textarea(value='', description='Question:', layout=Layout(height='80px', width='90%'), placeholder='Type your …
# Button(button_style='primary', description='Ask AI', style=ButtonStyle())
# Output()
